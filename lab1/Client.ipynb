# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.call() # start the call and print echo

client = clientserver.Client() # Create a client instance
client.get("Alice")

client = clientserver.Client() # Create a client instance
client.getall()
# Out:
# 2026-04-14 10:43:32,451 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 55180), raddr=('127.0.0.1', 50007)>
# 2026-04-14 10:43:32,454 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 2026-04-14 10:43:32,456 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 55190), raddr=('127.0.0.1', 50007)>
# 2026-04-14 10:43:32,457 - vs2lab.a1_layers.clientserver.Client - INFO - Sent: GET Alice
# 2026-04-14 10:43:32,459 - vs2lab.a1_layers.clientserver.Client - INFO - Received: OK Alice 123
# 2026-04-14 10:43:32,460 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 2026-04-14 10:43:32,462 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 55194), raddr=('127.0.0.1', 50007)>
# 2026-04-14 10:43:32,463 - vs2lab.a1_layers.clientserver.Client - INFO - Sent: GETALL
# 2026-04-14 10:43:32,467 - vs2lab.a1_layers.clientserver.Client - INFO - Received: OK
# Alice 123
# Bob 456
# Charlie 789
# END
# 2026-04-14 10:43:32,471 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# ERROR Unknown command
# OK Alice 123
# OK
# Alice 123
# Bob 456
# Charlie 789
# END
# 'OK\nAlice 123\nBob 456\nCharlie 789\nEND'

# %% [markdown]
# Finished.
