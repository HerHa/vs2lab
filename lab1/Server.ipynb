# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# 2026-04-14 10:43:22,836 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2026-04-14 10:43:32,453 - vs2lab.lab1.clientserver.Server - INFO - Received: Hello, world
# 2026-04-14 10:43:32,457 - vs2lab.lab1.clientserver.Server - INFO - Received: GET Alice
# 2026-04-14 10:43:32,463 - vs2lab.lab1.clientserver.Server - INFO - Received: GETALL
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 import clientserver # import from our script
#       2
#       3 server = clientserver.Server() # Create a server instance
#       4
# ----> 5 server.serve() # start server routine in the forked process
#
# File /workspaces/vs2lab/lab1/clientserver.py:65, in Server.serve(self)
#      62 while self._serving:  # as long as _serving (checked after connections or socket timeouts)
#      63     try:
#      64         # pylint: disable=unused-variable
# ---> 65         (connection, address) = self.sock.accept()  # returns new socket and address of client
#      66         while True:  # forever
#      67             data = connection.recv(1024)  # receive data from client
#
# File /usr/local/lib/python3.14/socket.py:298, in socket.accept(self)
#     291 def accept(self):
#     292     """accept() -> (socket object, address info)
#     293
#     294     Wait for an incoming connection.  Return a new socket
#     295     representing the connection, and the address of the client.
#     296     For IP sockets, the address info is a pair (hostaddr, port).
#     297     """
# --> 298     fd, addr = self._accept()
#     299     sock = socket(self.family, self.type, self.proto, fileno=fd)
#     300     # Issue #7995: if no default timeout is set and the listening
#     301     # socket had a (non-zero) timeout, force the new socket in blocking
#     302     # mode to override platform-specific socket flags inheritance.
#
# KeyboardInterrupt:
