# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import clientserver # import from our script

server = clientserver.Server() # Create a server instance

server.serve() # start server routine in the forked process
# Out:
# 2026-04-15 16:30:42,957 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=65, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2026-04-15 16:30:51,583 - vs2lab.lab1.clientserver.Server - INFO - Defaulting to echo for message: Test
# 2026-04-15 16:30:51,585 - vs2lab.lab1.clientserver.Server - INFO - Defaulting to echo for message: Lets go!
# 2026-04-15 16:31:05,476 - vs2lab.lab1.clientserver.Server - INFO - Requested Phone Number for Jamie
# 2026-04-15 16:31:05,479 - vs2lab.lab1.clientserver.Server - INFO - Requested Phone Number for Hannah
# 2026-04-15 16:31:05,481 - vs2lab.lab1.clientserver.Server - INFO - Requested Phone Number for Bec
# 2026-04-15 16:31:05,484 - vs2lab.lab1.clientserver.Server - INFO - Requested Phone Number for Unknown
# 2026-04-15 16:31:17,771 - vs2lab.lab1.clientserver.Server - INFO - Requested All Phone Numbers

# %% [markdown]
# Finished
